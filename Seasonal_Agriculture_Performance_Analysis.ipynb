# %% [markdown]
# # Seasonal Agriculture Performance Analysis
#
# Major Data Analytics Project
#
# **Domain**: Agriculture
#
# **Project Theme**: Seasonal Agriculture Performance
#
# **Tools**: Python, Pandas, NumPy, Matplotlib, Seaborn
#
# **Project Goal**
#
# Investigate how agricultural performance varies across seasons and identify meaningful patterns, trends, relationships and differences in the available data.

# %% [markdown]
# # Problem Statement
# Agricultural activities are influenced by seasonal variations in environmental conditions,farming practices, resource availability and market conditions.
#
# As a result, agricultural performance may differ from one season to another.
# However, raw agricultural data does not clearly explain how agricultural performance changes across seasons or what patterns can be observed in different seasonal conditions.
#
# The problem is to analyze the given agricultural dataset and investigate seasonal differences in agricultural performance by identifying meaningful patterns, trends, relationships and variations within the available data.

# %% [markdown]
# # Problem Objective
#
#
# *   Explore and understand the dataset.
# *   Clean and prepare the data for analysis.
# *   Examine how agricultural performance varies across seasons
# *   Identify important seasonal patterns and trends.
# *   Investigate relationships between seasonal conditions and agricultural outcomes.
# *   Compare relevant groups within different seasons.
# *   Identify significant differences or unusual patterns
# *   Apply appropriate statistical and visualization techniques.
# *   Interpret findings based on evidence from the dataset.
# *   Develop meaningful conclusions and data-driven recommendations.

# %% [markdown]
# # 1. Dataset loading
# The dataset represents agricultural activities carried out across different seasons,geographical areas and farming conditions. It contains information related to farming practices, environmental conditions, crop production, resource usage and economic performance.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import the data set
df = pd.read_csv("/content/seasonal_agriculture_performance_dataset.csv")

# %% [markdown]
# # 2. Rows

# %%
df.head()
# Out:
#    Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 0  SF10001  Andhra Pradesh    Rajkot   Wheat  Kharif                0.53
# 1  SF10002     Maharashtra  Nalgonda   Maize  Kharif                6.53
# 2  SF10003       Telangana  Warangal  Pulses    Rabi                4.86
# 3  SF10004       Telangana    Indore    Rice  Kharif                4.50
# 4  SF10005       Karnataka  Ludhiana   Maize    Zaid                4.21
#
#    Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  ...  \
# 0        486.4               24.3          69.1                 5.8  ...
# 1        855.4               25.7          78.4                 5.1  ...
# 2        455.6               23.9          56.4                10.3  ...
# 3        753.2               29.7          65.2                 6.3  ...
# 4        101.6               34.1          55.2                 6.5  ...
#
#    Seed_Quality_Score  Yield_Tonnes_Ha  Production_Tonnes  \
# ...

# %%
df.tail()
# Out:
#       Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 3995  SF13996       Karnataka    Rajkot   Wheat  Kharif                4.72
# 3996  SF13997       Karnataka   Krishna  Chilli  Kharif                8.77
# 3997  SF13998  Andhra Pradesh     Erode  Pulses    Zaid               10.47
# 3998  SF13999          Punjab  Warangal  Cotton  Kharif                1.73
# 3999  SF14000          Punjab    Nashik   Wheat  Kharif                3.31
#
#       Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  ...  \
# 3995        865.4               27.3          51.4                 6.3  ...
# 3996        947.5               29.2          85.5                 6.1  ...
# 3997         80.0               35.4          68.5                 8.6  ...
# 3998        475.0               28.2          61.7                 6.4  ...
# 3999        984.3               25.8          77.2                 5.9  ...
#
# ...

# %% [markdown]
# # 3. Dataset Shape and Structure Examining

# %%
df.shape
# Out:
# (4000, 28)

# %%
df.shape[0]
# Out:
# 4000

# %%
df.shape[1]
# Out:
# 28

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Farm_ID                        4000 non-null   object
#  1   State                          4000 non-null   object
#  2   District                       4000 non-null   object
#  3   Crop                           4000 non-null   object
#  4   Season                         4000 non-null   object
#  5   Farm_Area_Hectares             4000 non-null   float64
#  6   Rainfall_mm                    3952 non-null   float64
#  7   Avg_Temperature_C              4000 non-null   float64
#  8   Humidity_pct                   4000 non-null   float64
#  9   Sunlight_Hours_Day             4000 non-null   float64
#  10  Soil_pH                        4000 non-null   float64
#  11  Soil_Moisture_pct              3960 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Farm_Area_Hectares  Rainfall_mm  Avg_Temperature_C  Humidity_pct  \
# count         4000.000000  3952.000000         4000.00000   4000.000000
# mean             7.888265   601.152657           26.81890     63.210500
# std              4.223764   288.925025            3.81818     11.960834
# min              0.500000    80.000000           16.20000     25.000000
# 25%              4.260000   370.200000           23.90000     54.775000
# 50%              7.895000   582.000000           26.90000     63.000000
# 75%             11.650000   834.950000           29.60000     71.900000
# max             15.000000  1395.200000           39.70000     95.000000
#
#        Sunlight_Hours_Day      Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  \
# count         4000.000000  4000.000000        3960.000000     4000.000000
# mean             7.323050     6.701010          26.508232      120.250825
# std              1.121186     0.641461           6.712484       31.216452
# ...

# %%
df.describe(include='object')
# Out:
#         Farm_ID           State  District  Crop  Season Irrigation_Method
# count      4000            4000      4000  4000    4000              4000
# unique     4000               8        10     8       3                 4
# top     SF13984  Andhra Pradesh  Ludhiana  Rice  Kharif             Flood
# freq          1             529       427   690    1779              1310

# %% [markdown]
# # 4. Data types Examining

# %%
df.dtypes
# Out:
# Farm_ID                           object
# State                             object
# District                          object
# Crop                              object
# Season                            object
# Farm_Area_Hectares               float64
# Rainfall_mm                      float64
# Avg_Temperature_C                float64
# Humidity_pct                     float64
# Sunlight_Hours_Day               float64
# Soil_pH                          float64
# Soil_Moisture_pct                float64
# Nitrogen_kg_ha                   float64
# Phosphorus_kg_ha                 float64
# Potassium_kg_ha                  float64
# Irrigation_Method                 object
# Fertilizer_kg_ha                 float64
# Pesticide_Litre_ha               float64
# Seed_Quality_Score               float64
# Yield_Tonnes_Ha                  float64
# Production_Tonnes                float64
# Market_Price_INR_Tonne             int64
# Total_Cost_INR                     int64
# ...

# %%
df.sample(5, random_state = 31)
# Out:
#       Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 2139  SF12140  Andhra Pradesh  Ludhiana  Cotton  Kharif                0.61
# 2304  SF12305     Maharashtra    Rajkot    Rice    Zaid               10.56
# 2049  SF12050          Punjab  Warangal  Chilli  Kharif               10.29
# 2836  SF12837       Karnataka  Ludhiana  Cotton    Zaid                2.64
# 157   SF10158  Andhra Pradesh    Nashik  Cotton    Zaid                5.40
#
#       Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  ...  \
# 2139        774.5               29.2          75.8                 7.1  ...
# 2304        357.6               31.0          45.5                 8.4  ...
# 2049       1112.7               27.9          64.8                 6.8  ...
# 2836        305.6               25.7          50.1                 8.7  ...
# 157          80.0               30.2          64.5                 7.8  ...
#
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Farm_ID', 'State', 'District', 'Crop', 'Season', 'Farm_Area_Hectares', 'Rainfall_mm', 'Avg_Temperature_C', 'Humidity_pct', 'Sunlight_Hours_Day', 'Soil_pH', 'Soil_Moisture_pct', 'Nitrogen_kg_ha', 'Phosphorus_kg_ha', 'Potassium_kg_ha', 'Irrigation_Method', 'Fertilizer_kg_ha', 'Pesticide_Litre_ha', 'Seed_Quality_Score', 'Yield_Tonnes_Ha', 'Production_Tonnes', 'Market_Price_INR_Tonne', 'Total_Cost_INR', 'Revenue_INR', 'Profit_INR', 'Water_Used_m3', 'Water_Efficiency_t_per_1000m3', 'Disease_Pest_Risk_pct']

# %%
print(df["Season"].unique())
# Out:
# ['Kharif' 'Rabi' 'Zaid']

# %%
print(df["Crop"].unique())
# Out:
# ['Wheat' 'Maize' 'Pulses' 'Rice' 'Cotton' 'Chilli' 'Groundnut' 'Sugarcane']

# %%
print(df["State"].unique())
# Out:
# ['Andhra Pradesh' 'Maharashtra' 'Telangana' 'Karnataka' 'Gujarat'
#  'Tamil Nadu' 'Punjab' 'Madhya Pradesh']

# %% [markdown]
# # 5. Missing Values Indentifying and Handling

# %%
missing = pd.DataFrame({
    "Missing Count": df.isna().sum(),
    "Missing%": (df.isna().mean() * 100).round(2)
})

missing = missing[missing["Missing Count"] > 0]

missing = missing.sort_values(by="Missing%", ascending=False)

print(missing)
# Out:
#                    Missing Count  Missing%
# Rainfall_mm                   48       1.2
# Soil_Moisture_pct             40       1.0
# Yield_Tonnes_Ha               32       0.8

# %%
missing_values = df.isnull().sum()

print("Columns with missing values:")
print(missing_values[missing_values > 0])
# Out:
# Columns with missing values:
# Rainfall_mm          48
# Soil_Moisture_pct    40
# Yield_Tonnes_Ha      32
# dtype: int64

# %%
missing_values = df.isnull().sum()

missing_values = missing_values[missing_values > 0]

plt.figure(figsize=(10, 3))

sns.barplot(
    x=missing_values.values,
    y=missing_values.index
)

plt.title("Missing Values in Each Column")
plt.xlabel("Number of Missing Values")
plt.ylabel("Columns")

plt.tight_layout()
plt.show()

# %% [markdown]
# # 6. Duplicate Records Identifying and Handling

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Identify duplicate records

print("Duplicate records before handling:")
print(df_clean.duplicated().sum())

# Remove duplicate records
df_clean = df_clean.drop_duplicates()

print("\nDuplicate records after handling:")
print(df_clean.duplicated().sum())

print("\nDataset shape after removing duplicates:")
print(df_clean.shape)
# Out:
# Duplicate records before handling:
# 0
#
# Duplicate records after handling:
# 0
#
# Dataset shape after removing duplicates:
# (4000, 29)

# %% [markdown]
# # 7. Descriptive/Statistical Analysis Performing

# %%
# Descriptive / Statistical Analysis

descriptive_stats = df.describe().T[['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max']]

descriptive_stats = descriptive_stats.round(2)

display(descriptive_stats)
# Out:
#                                 count       mean        std         min  \
# Farm_Area_Hectares             4000.0       7.89       4.22        0.50
# Rainfall_mm                    3952.0     601.15     288.93       80.00
# Avg_Temperature_C              4000.0      26.82       3.82       16.20
# Humidity_pct                   4000.0      63.21      11.96       25.00
# Sunlight_Hours_Day             4000.0       7.32       1.12        3.50
# Soil_pH                        4000.0       6.70       0.64        5.20
# Soil_Moisture_pct              3960.0      26.51       6.71        8.00
# Nitrogen_kg_ha                 4000.0     120.25      31.22       40.00
# Phosphorus_kg_ha               4000.0      57.78      17.02       15.00
# Potassium_kg_ha                4000.0     104.76      27.74       30.00
# Fertilizer_kg_ha               4000.0     186.04      60.26       40.00
# Pesticide_Litre_ha             4000.0       5.07       1.98        0.50
# ...

# %%
# Descriptive / Statistical Analysis

print("\nMean:")
print(df_clean.select_dtypes(include='number').mean())

print("\nMedian:")
print(df_clean.select_dtypes(include='number').median())

print("\nStandard Deviation:")
print(df_clean.select_dtypes(include='number').std())
# Out:
# Mean:
# Farm_Area_Hectares                    7.888265
# Rainfall_mm                         600.922825
# Avg_Temperature_C                    26.818900
# Humidity_pct                         63.210500
# Sunlight_Hours_Day                    7.323050
# Soil_pH                               6.701010
# Soil_Moisture_pct                    26.507150
# Nitrogen_kg_ha                      120.250825
# Phosphorus_kg_ha                     57.781850
# Potassium_kg_ha                     104.760050
# Fertilizer_kg_ha                    186.036000
# Pesticide_Litre_ha                    5.070935
# Seed_Quality_Score                    0.826138
# Yield_Tonnes_Ha                       5.242350
# Production_Tonnes                    43.246210
# Market_Price_INR_Tonne            44714.166250
# Total_Cost_INR                   526303.583000
# Revenue_INR                      637860.048000
# Profit_INR                       111556.465000
# Water_Used_m3                      6045.570250
# ...

# %% [markdown]
# # 8. Outliers Investigating

# %%
# Investigate Outliers using IQR Method
numeric_columns = df_clean.select_dtypes(include='number').columns
outlier_summary = {}
for col in numeric_columns:
    Q1 = df_clean[col].quantile(0.25)
    Q3 = df_clean[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df_clean[
        (df_clean[col] < lower_bound) |
        (df_clean[col] > upper_bound)
    ]
    outlier_summary[col] = len(outliers)
print("Outlier Count for Each Numerical Column:")
for col, count in outlier_summary.items():
    print(f"{col}: {count}")
print("\nOutlier investigation completed successfully.")
# Out:
# Outlier Count for Each Numerical Column:
# Farm_Area_Hectares: 0
# Rainfall_mm: 0
# Avg_Temperature_C: 2
# Humidity_pct: 6
# Sunlight_Hours_Day: 26
# Soil_pH: 0
# Soil_Moisture_pct: 5
# Nitrogen_kg_ha: 10
# Phosphorus_kg_ha: 16
# Potassium_kg_ha: 32
# Fertilizer_kg_ha: 15
# Pesticide_Litre_ha: 8
# Seed_Quality_Score: 0
# Yield_Tonnes_Ha: 302
# Production_Tonnes: 333
# Market_Price_INR_Tonne: 0
# Total_Cost_INR: 0
# Revenue_INR: 240
# Profit_INR: 404
# Water_Used_m3: 276
# Water_Efficiency_t_per_1000m3: 322
# Disease_Pest_Risk_pct: 10
#
# Outlier investigation completed successfully.

# %% [markdown]
# # 9. Univariate Analysis

# %%
# Univariate Analysis
# Numerical columns
numeric_columns = df_clean.select_dtypes(include='number').columns

# Statistical summary
print("Univariate Statistical Summary:")
display(df_clean[numeric_columns].describe())

# Create plots
n = len(numeric_columns)
cols = 6
rows = (n + cols - 1) // cols
fig, axes = plt.subplots(rows, cols, figsize=(25, 5 * rows))
axes = axes.flatten()

for i, col in enumerate(numeric_columns):
    sns.histplot(df_clean[col], kde=True, ax=axes[i])
    axes[i].set_title(f"Distribution of {col}")
    axes[i].set_xlabel(col)
    axes[i].set_ylabel("Frequency")

    # Hide unused plots
for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)

plt.tight_layout()
plt.show()
# Out:
# Univariate Statistical Summary:
#        Farm_Area_Hectares  Rainfall_mm  Avg_Temperature_C  Humidity_pct  \
# count         4000.000000  4000.000000         4000.00000   4000.000000
# mean             7.888265   600.922825           26.81890     63.210500
# std              4.223764   287.193381            3.81818     11.960834
# min              0.500000    80.000000           16.20000     25.000000
# 25%              4.260000   371.575000           23.90000     54.775000
# 50%              7.895000   582.000000           26.90000     63.000000
# 75%             11.650000   831.975000           29.60000     71.900000
# max             15.000000  1395.200000           39.70000     95.000000
#
#        Sunlight_Hours_Day      Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  \
# count         4000.000000  4000.000000        4000.000000     4000.000000
# mean             7.323050     6.701010          26.507150      120.250825
# ...

# %% [markdown]
# # 10. Bivariate Analysis

# %%
# Bivariate Analysis

import matplotlib.pyplot as plt
import seaborn as sns

# Select numerical columns
numeric_columns = df_clean.select_dtypes(include='number').columns

# Correlation matrix
print("Correlation Matrix:")
display(df_clean[numeric_columns].corr())
# Out:
# Correlation Matrix:
#                                Farm_Area_Hectares  Rainfall_mm  \
# Farm_Area_Hectares                       1.000000     0.007256
# Rainfall_mm                              0.007256     1.000000
# Avg_Temperature_C                        0.036870     0.198492
# Humidity_pct                             0.000471     0.521069
# Sunlight_Hours_Day                       0.001821    -0.362779
# Soil_pH                                  0.009857     0.016657
# Soil_Moisture_pct                        0.004033     0.508941
# Nitrogen_kg_ha                           0.013658     0.007460
# Phosphorus_kg_ha                        -0.006625     0.020940
# Potassium_kg_ha                          0.000195     0.031373
# Fertilizer_kg_ha                         0.014975     0.024602
# Pesticide_Litre_ha                      -0.005207     0.004058
# Seed_Quality_Score                       0.015236    -0.018581
# Yield_Tonnes_Ha                          0.030203     0.030951
# ...

# %% [markdown]
# # 11. Multivariate Analysis

# %%
# Multivariate Analysis using 5 important variables
selected_columns = ["Disease_Pest_Risk_pct","Yield_Tonnes_Ha","Rainfall_mm","Temperature_C","Fertilizer_Usage_kg_Ha"]
# Check available columns
available_columns = [col for col in selected_columns if col in df_clean.columns]

print("Variables used:")
print(available_columns)

# Create pairplot
sns.pairplot(
    df_clean[available_columns],
    diag_kind="hist"
)

plt.suptitle(
    "Multivariate Analysis of Agricultural Variables",
    y=1.02
)

plt.show()
# Out:
# Variables used:
# ['Disease_Pest_Risk_pct', 'Yield_Tonnes_Ha', 'Rainfall_mm']

# %%
# Multivariate Scatter Plot using 3 variables

if all(col in df_clean.columns for col in [
    "Disease_Pest_Risk_pct",
    "Yield_Tonnes_Ha"
]):

    plt.figure(figsize=(9, 6))

    sns.scatterplot(
        data=df_clean,
        x="Disease_Pest_Risk_pct",
        y="Yield_Tonnes_Ha",
        hue=df_clean.select_dtypes(include='number').columns[0],
        size=df_clean.select_dtypes(include='number').columns[0],
        alpha=0.7
    )

    plt.title("Multivariate Analysis")
    plt.xlabel("Disease/Pest Risk (%)")
    plt.ylabel("Yield (Tonnes/Ha)")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #12. Corrlation Analysis

# %%
# Correlation Analysis

# Select numerical columns
numeric_columns = df_clean.select_dtypes(include='number').columns

# Calculate correlation matrix
correlation_matrix = df_clean[numeric_columns].corr()

print("Correlation Matrix:")
display(correlation_matrix)

# Plot correlation heatmap
plt.figure(figsize=(12, 8))

sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap="coolwarm",
    fmt=".2f",
    linewidths=0.5
)

plt.title("Correlation Analysis of Numerical Variables")
plt.tight_layout()
plt.show()
# Out:
# Correlation Matrix:
#                                Farm_Area_Hectares  Rainfall_mm  \
# Farm_Area_Hectares                       1.000000     0.007256
# Rainfall_mm                              0.007256     1.000000
# Avg_Temperature_C                        0.036870     0.198492
# Humidity_pct                             0.000471     0.521069
# Sunlight_Hours_Day                       0.001821    -0.362779
# Soil_pH                                  0.009857     0.016657
# Soil_Moisture_pct                        0.004033     0.508941
# Nitrogen_kg_ha                           0.013658     0.007460
# Phosphorus_kg_ha                        -0.006625     0.020940
# Potassium_kg_ha                          0.000195     0.031373
# Fertilizer_kg_ha                         0.014975     0.024602
# Pesticide_Litre_ha                      -0.005207     0.004058
# Seed_Quality_Score                       0.015236    -0.018581
# Yield_Tonnes_Ha                          0.030203     0.030951
# ...

# %% [markdown]
# # 13. Seasonal Comparisons Performing

# %%
# Seasonal Comparisons
# Check season-wise average values
seasonal_summary = df_clean.groupby("Season").mean(numeric_only=True)

print("Seasonal Comparison:")
display(seasonal_summary)

# Select important numerical variables
variables = [
    "Yield_Tonnes_Ha",
    "Disease_Pest_Risk_pct"
]

available_variables = [col for col in variables if col in df_clean.columns]

# Seasonal plots
fig, axes = plt.subplots(1, len(available_variables),figsize=(14, 5))

if len(available_variables) == 1:
    axes = [axes]
for i, col in enumerate(available_variables):
    sns.barplot(data=df_clean,x="Season",y=col,estimator="mean",errorbar=None,ax=axes[i])

    axes[i].set_title(f"Average {col} by Season")
    axes[i].set_xlabel("Season")
    axes[i].set_ylabel(col)

plt.tight_layout()
plt.show()
# Out:
# Seasonal Comparison:
#         Farm_Area_Hectares  Rainfall_mm  Avg_Temperature_C  Humidity_pct  \
# Season
# Kharif            7.944924   849.199663          28.454019     71.812591
# Rabi              7.752207   437.615366          23.489183     57.893178
# Zaid              8.091246   304.654714          31.042088     52.012121
#
#         Sunlight_Hours_Day   Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  \
# Season
# Kharif            6.793367  6.727993          31.149859      120.020124
# Rabi              7.589797  6.673749          24.069392      120.402827
# Zaid              8.178788  6.694865          19.279630      120.525421
#
#         Phosphorus_kg_ha  Potassium_kg_ha  ...  Seed_Quality_Score  \
# Season                                     ...
# Kharif         58.096515       105.303485  ...            0.821613
# Rabi           57.311002       103.926060  ...            0.832170
# Zaid           58.129125       105.416835  ...            0.823165
#
# ...

# %% [markdown]
# # 14. At least 3-Designed Analyses
#
#   # 1. Yield Efficiency Analysis

# %%
 # Yield Efficiency


plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df_clean,
    x="Disease_Pest_Risk_pct",
    y="Yield_Tonnes_Ha"
)

plt.title("Disease/Pest Risk vs Crop Yield")
plt.xlabel("Disease/Pest Risk (%)")
plt.ylabel("Yield (Tonnes/Ha)")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Risk Categories

# %%
# Risk Categories

df_clean["Risk_Category"] = pd.cut(df_clean["Disease_Pest_Risk_pct"],bins=[-1, 25, 50, 75, 100],labels=["Low", "Moderate", "High", "Very High"])
risk_summary = df_clean.groupby(
    "Risk_Category",
    observed=False
)["Yield_Tonnes_Ha"].mean().reset_index()
print("Average Yield by Risk Category:")
display(risk_summary)
plt.figure(figsize=(3, 5))
sns.barplot( data=risk_summary, x="Risk_Category", y="Yield_Tonnes_Ha")
plt.title("Average Yield by Disease/Pest Risk Category")
plt.xlabel("Risk Category")
plt.ylabel("Average Yield (Tonnes/Ha)")
plt.tight_layout()
plt.show()
# Out:
# Average Yield by Risk Category:
#   Risk_Category  Yield_Tonnes_Ha
# 0           Low         4.894740
# 1      Moderate         5.120614
# 2          High         5.470521
# 3     Very High         5.073784

# %% [markdown]
# # 3. Seasonal Yield Comparison

# %%
# Student-Designed Analysis 3

seasonal_yield = df_clean.groupby("Season",observed=False)["Yield_Tonnes_Ha"].mean().reset_index()
print("Average Yield by Season:")
display(seasonal_yield)
plt.figure(figsize=(3, 4))
sns.barplot(data=seasonal_yield,x="Season",y="Yield_Tonnes_Ha")
plt.title("Average Crop Yield by Season")
plt.xlabel("Season")
plt.ylabel("Average Yield (Tonnes/Ha)")
plt.tight_layout()
plt.show()
# Out:
# Average Yield by Season:
#    Season  Yield_Tonnes_Ha
# 0  Kharif         5.628612
# 1    Rabi         5.039435
# 2    Zaid         4.641313

# %% [markdown]
# # 15. At Least 8 Meaningful Insights

# %%
# 8 Meaningful Insights

# 1. Highest Yield
highest_yield = df_clean.loc[df_clean["Yield_Tonnes_Ha"].idxmax()]
print("1. Highest Yield:")
print(f"   The highest recorded yield is "
      f"{highest_yield['Yield_Tonnes_Ha']:.2f} tonnes/ha.\n")
# 2. Lowest Yield
lowest_yield = df_clean.loc[df_clean["Yield_Tonnes_Ha"].idxmin()]
print("2. Lowest Yield:")
print(f"   The lowest recorded yield is "
      f"{lowest_yield['Yield_Tonnes_Ha']:.2f} tonnes/ha.\n")
# 3. Average Yield
average_yield = df_clean["Yield_Tonnes_Ha"].mean()
print("3. Average Yield:")
print(f"   The average crop yield is "
      f"{average_yield:.2f} tonnes/ha.\n")
# 4. Average Disease/Pest Risk
average_risk = df_clean["Disease_Pest_Risk_pct"].mean()
print("4. Average Disease/Pest Risk:")
print(f"   The average disease/pest risk is "
      f"{average_risk:.2f}%.\n")
# 5. Highest Disease/Pest Risk
highest_risk = df_clean["Disease_Pest_Risk_pct"].max()
print("5. Highest Disease/Pest Risk:")
print(f"   The highest disease/pest risk recorded is "
      f"{highest_risk:.2f}%.\n")
# 6. Lowest Disease/Pest Risk
lowest_risk = df_clean["Disease_Pest_Risk_pct"].min()
print("6. Lowest Disease/Pest Risk:")
print(f"   The lowest disease/pest risk recorded is "
      f"{lowest_risk:.2f}%.\n")
# 7. Correlation between Risk and Yield
correlation = df_clean["Disease_Pest_Risk_pct"].corr(df_clean["Yield_Tonnes_Ha"])
print("7. Disease/Pest Risk and Yield Relationship:")
print(f"   The correlation coefficient is "
      f"{correlation:.2f}.\n")
if correlation < 0:
    print("   This indicates a negative relationship: "
          "higher disease/pest risk tends to be associated "
          "with lower yield.\n")
elif correlation > 0:
    print("   This indicates a positive relationship: "
          "higher disease/pest risk tends to be associated "
          "with higher yield.\n")
else:
    print("   There is little or no linear relationship "
          "between the two variables.\n")


# 8. Best Season
if "Season" in df_clean.columns:
    seasonal_yield = df_clean.groupby(
        "Season",
        observed=False
    )["Yield_Tonnes_Ha"].mean()

    best_season = seasonal_yield.idxmax()
    best_season_yield = seasonal_yield.max()

    print("8. Best Performing Season:")
    print(f"   {best_season} has the highest average yield "
          f"of {best_season_yield:.2f} tonnes/ha.")
# Out:
# 1. Highest Yield:
#    The highest recorded yield is 101.44 tonnes/ha.
#
# 2. Lowest Yield:
#    The lowest recorded yield is 0.30 tonnes/ha.
#
# 3. Average Yield:
#    The average crop yield is 5.24 tonnes/ha.
#
# 4. Average Disease/Pest Risk:
#    The average disease/pest risk is 46.37%.
#
# 5. Highest Disease/Pest Risk:
#    The highest disease/pest risk recorded is 88.90%.
#
# 6. Lowest Disease/Pest Risk:
#    The lowest disease/pest risk recorded is 5.00%.
#
# 7. Disease/Pest Risk and Yield Relationship:
#    The correlation coefficient is 0.01.
#
#    This indicates a positive relationship: higher disease/pest risk tends to be associated with higher yield.
#
# 8. Best Performing Season:
#    Kharif has the highest average yield of 5.63 tonnes/ha.

# %%
categorical_columns = ['State', 'District', 'Crop', 'Season', 'Irrigation_Method']

for col in categorical_columns:
    print(f"\n{col}:")
    print(df[col].unique())
# Out:
# State:
# ['Andhra Pradesh' 'Maharashtra' 'Telangana' 'Karnataka' 'Gujarat'
#  'Tamil Nadu' 'Punjab' 'Madhya Pradesh']
#
# District:
# ['Rajkot' 'Nalgonda' 'Warangal' 'Indore' 'Ludhiana' 'Raichur' 'Guntur'
#  'Krishna' 'Nashik' 'Erode']
#
# Crop:
# ['Wheat' 'Maize' 'Pulses' 'Rice' 'Cotton' 'Chilli' 'Groundnut' 'Sugarcane']
#
# Season:
# ['Kharif' 'Rabi' 'Zaid']
#
# Irrigation_Method:
# ['Drip' 'Flood' 'Rainfed' 'Sprinkler']

# %%
# 1. Identifier Variables
identifier_variables = ['Farm_ID']

print("Identifier Variables")
print(identifier_variables)
# Out:
# Identifier Variables
# ['Farm_ID']

# %%
# 2. Categorical Variables
print("Categorical Variables")

for col in categorical_variables:
    print("-", col)
# Out:
# Categorical Variables
# - State
# - District
# - Crop
# - Season
# - Irrigation_Method

# %%
# 3. Numerical columns
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns

print("NUMERICAL COLUMNS")
print("-----------------")
for col in numerical_columns:
    print(col)
# Out:
# NUMERICAL COLUMNS
# -----------------
# Farm_Area_Hectares
# Rainfall_mm
# Avg_Temperature_C
# Humidity_pct
# Sunlight_Hours_Day
# Soil_pH
# Soil_Moisture_pct
# Nitrogen_kg_ha
# Phosphorus_kg_ha
# Potassium_kg_ha
# Fertilizer_kg_ha
# Pesticide_Litre_ha
# Seed_Quality_Score
# Yield_Tonnes_Ha
# Production_Tonnes
# Market_Price_INR_Tonne
# Total_Cost_INR
# Revenue_INR
# Profit_INR
# Water_Used_m3
# Water_Efficiency_t_per_1000m3
# Disease_Pest_Risk_pct

# %%
# 4. Environmental Variables
environmental_variables = ['Rainfall_mm','Avg_Temperature_C', 'Humidity_pct', 'Sunlight_Hours_Day', 'Soil_pH', 'Soil_Moisture_pct']

print("Environmental Variables")
print(environmental_variables)
# Out:
# Environmental Variables
# ['Rainfall_mm', 'Avg_Temperature_C', 'Humidity_pct', 'Sunlight_Hours_Day', 'Soil_pH', 'Soil_Moisture_pct']

# %%
# 5. Operational Variables
operational_variables = ['Farm_Area_Hectares','Irrigation_Method','Fertilizer_kg_ha','Pesticide_Litre_ha','Seed_Quality_Score','Nitrogen_kg_ha','Phosphorus_kg_ha','Potassium_kg_ha','Water_Used_m3']

print("Operational Variables")
print(operational_variables)
# Out:
# Operational Variables
# ['Farm_Area_Hectares', 'Irrigation_Method', 'Fertilizer_kg_ha', 'Pesticide_Litre_ha', 'Seed_Quality_Score', 'Nitrogen_kg_ha', 'Phosphorus_kg_ha', 'Potassium_kg_ha', 'Water_Used_m3']

# %%
# 6. Production/performance variables
production_performance_variables = [
    'Yield_Tonnes_Ha',
    'Production_Tonnes',
    'Water_Efficiency_t_per_1000m3',
    'Disease_Pest_Risk_pct'
]

print("Production/Performance Variables")
print(production_performance_variables)
# Out:
# Production/Performance Variables
# ['Yield_Tonnes_Ha', 'Production_Tonnes', 'Water_Efficiency_t_per_1000m3', 'Disease_Pest_Risk_pct']

# %%
# 7. Economic Variables
economic_variables = ['Market_Price_INR_Tonne','Total_Cost_INR','Revenue_INR','Profit_INR']

print("Economic Variables")
print(economic_variables)
# Out:
# Economic Variables
# ['Market_Price_INR_Tonne', 'Total_Cost_INR', 'Revenue_INR', 'Profit_INR']

# %%
# Most relevant variables for Seasonal Performance Analysis

relevant_variables = { 'Season': 'Main variable for comparing agricultural performance across seasons.', 'Yield_Tonnes_Ha': 'Measures crop productivity per hectare.', 'Production_Tonnes': 'Measures total agricultural output.', 'Rainfall_mm': 'Helps explain the effect of seasonal rainfall on crop performance.', 'Avg_Temperature_C': 'Seasonal temperature can affect crop growth and yield.','Soil_Moisture_pct': 'Shows the availability of water in the soil.',
    'Irrigation_Method': 'Represents irrigation practices that can affect crop performance.', 'Fertilizer_kg_ha': 'Shows fertilizer usage that may influence crop growth and yield.', 'Water_Used_m3': 'Helps evaluate water usage across seasons.', 'Disease_Pest_Risk_pct': 'Shows disease and pest risk that may vary by season.', 'Profit_INR': 'Measures the economic performance of farming across seasons.', 'Crop': 'Allows seasonal performance to be compared between different crops.',
    'State': 'Helps identify geographical differences in seasonal performance.','District': 'Provides detailed geographical comparison.'}

# Create table
relevance_df = pd.DataFrame(
    list(relevant_variables.items()),
    columns=['Variable', 'Why It Is Relevant'])

# Display table
print("Most Relevant Variables for Seasonal Performance")
display(relevance_df)
# Out:
# Most Relevant Variables for Seasonal Performance
#                  Variable                                 Why It Is Relevant
# 0                  Season  Main variable for comparing agricultural perfo...
# 1         Yield_Tonnes_Ha            Measures crop productivity per hectare.
# 2       Production_Tonnes                Measures total agricultural output.
# 3             Rainfall_mm  Helps explain the effect of seasonal rainfall ...
# 4       Avg_Temperature_C  Seasonal temperature can affect crop growth an...
# 5       Soil_Moisture_pct       Shows the availability of water in the soil.
# 6       Irrigation_Method  Represents irrigation practices that can affec...
# 7        Fertilizer_kg_ha  Shows fertilizer usage that may influence crop...
# 8           Water_Used_m3         Helps evaluate water usage across seasons.
# 9   Disease_Pest_Risk_pct  Shows disease and pest risk that may vary by s...
# 10             Profit_INR  Measures the economic performance of farming a...
# ...

# %% [markdown]
# # 16. Evidence Based Recommendations

# %%
# Evidence-Based Recommendations

correlation = df_clean[
    "Disease_Pest_Risk_pct"
].corr(
    df_clean["Yield_Tonnes_Ha"]
)

average_risk = df_clean["Disease_Pest_Risk_pct"].mean()
average_yield = df_clean["Yield_Tonnes_Ha"].mean()

print("========== EVIDENCE-BASED RECOMMENDATIONS ==========\n")

# Recommendation 1
if correlation < 0:
    print("1. Disease and pest management should be strengthened, "
          "as higher disease/pest risk is associated with lower crop yield.")
else:
    print("1. Disease and pest management should continue to be monitored "
          "because disease/pest risk shows a measurable relationship with yield.")

# Recommendation 2
print(f"\n2. Regular monitoring should be carried out because the "
      f"average disease/pest risk in the dataset is {average_risk:.2f}%.")

# Recommendation 3
if "Season" in df_clean.columns:
    seasonal_yield = df_clean.groupby(
        "Season",
        observed=False
    )["Yield_Tonnes_Ha"].mean()

    best_season = seasonal_yield.idxmax()
    best_yield = seasonal_yield.max()

    print(f"\n3. Agricultural activities should be planned carefully around "
          f"seasonal performance. {best_season} recorded the highest "
          f"average yield of {best_yield:.2f} tonnes/ha.")

# Recommendation 4
print(f"\n4. Farming practices should aim to maintain or exceed the "
      f"overall average yield of {average_yield:.2f} tonnes/ha.")

# Recommendation 5
print("\n5. Fields with higher disease/pest risk should receive "
      "priority for inspection and preventive management.")

# Recommendation 6
print("\n6. Seasonal yield patterns should be considered when planning "
      "crop production, resource allocation, and farm management.")

print("\nEvidence-based recommendations completed successfully.")
# Out:
# ========== EVIDENCE-BASED RECOMMENDATIONS ==========
#
# 1. Disease and pest management should continue to be monitored because disease/pest risk shows a measurable relationship with yield.
#
# 2. Regular monitoring should be carried out because the average disease/pest risk in the dataset is 46.37%.
#
# 3. Agricultural activities should be planned carefully around seasonal performance. Kharif recorded the highest average yield of 5.63 tonnes/ha.
#
# 4. Farming practices should aim to maintain or exceed the overall average yield of 5.24 tonnes/ha.
#
# 5. Fields with higher disease/pest risk should receive priority for inspection and preventive management.
#
# 6. Seasonal yield patterns should be considered when planning crop production, resource allocation, and farm management.
#
# Evidence-based recommendations completed successfully.

# %% [markdown]
# # 17. Limitations

# %% [markdown]
# 1. The analysis is limited to the variables available in the dataset.
#
# 2. Missing values and duplicate records were handled, which may slightly
#    affect the final results.
#
# 3. Outliers were identified using the IQR method, but they were not
#    necessarily removed because they may represent genuine observations.
#
# 4. Correlation analysis identifies relationships between variables but
#    does not prove cause-and-effect relationships.
#
# 5. Seasonal comparisons may not fully represent long-term agricultural
#    patterns if the dataset covers a limited number of years.
#
# 6. The dataset may not include all factors affecting crop yield, such as
#    soil quality, irrigation, crop variety, farming practices, and weather
#    conditions.
#
# 7. The findings are based on the available observations and may not be
#    directly generalizable to other regions or agricultural conditions.
#
# 8. Some student-designed analyses depend on the availability and quality
#    of specific variables in the dataset.
#
# 9. The accuracy of the conclusions depends on the accuracy and reliability
#    of the original data.
#
# 10. The analysis provides evidence-based observations, but further
#     real-world studies and additional data would be required for stronger
#     conclusions.

# %% [markdown]
# # 18. Final Conclusion
